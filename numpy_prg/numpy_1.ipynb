# %%
import numpy as np

# %%
a = np.array([1, 2, 3])

# %%
print(type(a))                         # to print type 
print(a[0], a[1], a[2])                # to print the weights
# Out:
# <class 'numpy.ndarray'>
# 1 2 3
