# %%
import numpy as np

# %%
b = np.array([[1,2,3],[4,5,6]])    # Create a rank 2 array
print (b)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(b[0,0])
print(b[0,1])
print(b[0,2])
print(b[1,0])
print(b[1,1])
print(b[1,2])
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
b[0,0] = 7
print (b)
# Out:
# [[7 2 3]
#  [4 5 6]]
